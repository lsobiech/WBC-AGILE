# %% [markdown]
# <a href="https://colab.research.google.com/github/lsobiech/WBC-AGILE/blob/main/Submission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
import shutil

shutil.unpack_archive('part1/Images.zip', '')
labels_df = pd.read_csv('part1/labels.csv', header=None)
labels_df_columns = ['image_id','class','x_min','y_min','x_max','y_max']
labels_df.columns = labels_df_columns
labels_df['image_id'] = labels_df['image_id'].apply(lambda x: f"{x:08d}")
# print(labels_df)
labels_df.iloc[:1000]
labels_df.shape
# Out:
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# /tmp/ipykernel_1867/2127816906.py in <cell line: 0>()
#       8 import shutil
#       9
# ---> 10 shutil.unpack_archive('part1/Images.zip')
#      11 labels_df = pd.read_csv('part1/labels.csv', header=None)
#      12 labels_df_columns = ['image_id','class','x_min','y_min','x_max','y_max']
#
# /usr/lib/python3.12/shutil.py in unpack_archive(filename, extract_dir, format, filter)
#    1349         func = _UNPACK_FORMATS[format][1]
#    1350         kwargs = dict(_UNPACK_FORMATS[format][2]) | filter_kwargs
# -> 1351         func(filename, extract_dir, **kwargs)
#    1352
#    1353
#
# /usr/lib/python3.12/shutil.py in _unpack_zipfile(filename, extract_dir)
#    1236
#    1237     if not zipfile.is_zipfile(filename):
# -> 1238         raise ReadError("%s is not a zip file" % filename)
#    1239
# ...
